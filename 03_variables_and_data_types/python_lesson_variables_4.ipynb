# %% [markdown]
# <a href="https://colab.research.google.com/github/NikoriakViktot/PY-Course-Victor-Nikoriak-23_02/blob/main/python_lesson_variables_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Урок: Змінні та примітивні типи даних

# %% [markdown]
# # ⚠️ Перед початком
#
# 1. File → Save a copy in Drive
# 2. Працюємо тільки у власній копії
# 3. Виконуйте клітинки зверху вниз

# %%
# @title 🔒 Натисніть Run ОДИН раз перед уроком
# 🔒 system cell (не змінювати)

import requests

SYSTEM_READY = True
COMPLETED_TASKS = set()

try:
    STUDENT_NAME
except NameError:
    STUDENT_NAME = None

def require_system():

    if "SYSTEM_READY" not in globals():
        print("⛔ Спочатку натисніть:")
        print("👉 🔒 Натисніть Run ОДИН раз перед уроком")
        return False

    return True

def require_student():

    if not require_system():
        return False

    global STUDENT_NAME

    if STUDENT_NAME is None or str(STUDENT_NAME).strip() == "":
        print("⛔ Спочатку представтесь 👇")
        print("👉 Запустіть клітинку '👤 Представтесь'")
        return False

    return True


def submit_task(name, lesson, task):
      key = f"{lesson}_{task}"
      if key in COMPLETED_TASKS:
        print("⚠️ Завдання вже зараховано")
        return
      if not require_student():
            return

      url = "https://docs.google.com/forms/d/e/1FAIpQLSfZOPkzWV8T90ULhISvLhL1RxaFgNStc0y1RvRofe93sw-9tQ/formResponse"

      data = {
        "entry.575335391": name,
        "entry.1320852544": lesson,
        "entry.705949827": task
    }

      requests.post(url, data=data)
      COMPLETED_TASKS.add(key)
      print("✅ Завдання зараховано")

def submit_group_result(group, value):

    if not require_student():
        return

    url = "https://docs.google.com/forms/d/e/1FAIpQLSfZOPkzWV8T90ULhISvLhL1RxaFgNStc0y1RvRofe93sw-9tQ/formResponse"

    data = {
        "entry.575335391": STUDENT_NAME,
        "entry.1320852544": "FinalProject",
        "entry.705949827": f"{group}:{value}"
    }

    requests.post(url, data=data)

    print(f"✅ Результат групи {group} відправлено")

print("🔧 System ready:", "SYSTEM_READY" in globals())
# Out:
# 🔧 System ready: True

# %% [markdown]
# ## 👤 Крок 0 — представтесь
#
# Вкажіть своє ім'я.

# %%
#@title 👤 Представтесь

STUDENT_NAME = "" #@param {type:"string"}

if not require_student():
    raise SystemExit

if STUDENT_NAME.strip() == "":
    raise ValueError("⚠️ Введіть ім'я")

print("✅ Привіт,", STUDENT_NAME)

# %% [markdown]
# # Конспект: Змінні та примітивні типи даних у Python

# %% [markdown]
# ---
#
# ## 1. Змінні (Variables)
#
# Змінні у Python діють як **посилання** або *"ярлики"*, які вказують на об'єкти в пам’яті, а не як "коробки" для зберігання значень.
#
# ---
#
# ### 🔹 Створення змінної
#
# Змінна створюється в момент присвоювання значення за допомогою оператора `=`.
#
# ```python
# a = 5
# ````
#
# У цьому випадку:
#
# * створюється об'єкт цілого числа `5`
# * ім'я `a` починає посилатися на цей об'єкт
#
# ---
#
# ### 🔹 Динамічна типізація
#
# У Python **не потрібно оголошувати тип змінної наперед**.
#
# Одна змінна може посилатися на різні типи даних у різний час:
#
# ```python
# x = 10
# x = "hello"
# ```
#
# ---
#
# ### 🔹 Правила іменування змінних
#
# Імена можуть містити:
#
# * літери
# * цифри
# * символ підкреслення `_`
#
# Обмеження:
#
# * ім'я **не може починатися з цифри**
# * не допускаються пробіли
# * Python чутливий до регістру
#
# ```python
# spam != Spam
# ```
#
# ✅ Згідно зі стандартом **PEP 8**, використовують нижній регістр:
#
# ```python
# user_age
# total_sum
# ```
#
# ---
#
# ### 🔹 Копіювання змінних
#
# ```python
# b = a
# ```
#
# Це **не копіює об'єкт**, а створює нове посилання на той самий об'єкт у пам’яті.
#
# ---
#
# ## 2. Примітивні типи даних (Primitive Data Types)
#
# Кожен об'єкт у Python має тип, який визначає можливі операції над ним.
#
# ---
#
# ### 🔹 `int` — цілі числа
#
# ```python
# 42
# -5
# ```
#
# У Python 3 мають практично необмежену довжину.
#
# ---
#
# ### 🔹 `float` — числа з плаваючою крапкою
#
# ```python
# 3.14
# -1.2
# ```
#
# ---
#
# ### 🔹 `str` — рядки
#
# Текстові дані (послідовність символів).
#
# ```python
# "text"
# 'hello'
# ```
#
# ⚠️ **Рядки є незмінними (immutable).**
#
# Після створення рядка його внутрішній вміст змінити неможливо.
#
# #### Основні принципи незмінності рядків
#
# **1. Заборона модифікації "на місці"**
#
# ```python
# s = "abc"
# s[0] = "x"
# ```
#
# Викличе помилку:
#
# ```
# TypeError: 'str' object does not support item assignment
# ```
#
# ---
#
# **2. Створення нового об'єкта**
#
# Будь-яка операція, що виглядає як зміна рядка, створює новий об'єкт:
#
# ```python
# s = "hello"
# s = s + " world"
# ```
#
# Старий рядок не змінюється.
#
# ---
#
# **3. Гарантія цілісності даних**
#
# Незмінність дозволяє використовувати рядки як:
#
# * ключі словників (`dict`)
# * елементи множин (`set`)
#
# Їхній хеш залишається стабільним.
#
# ---
#
# **4. Оптимізація пам'яті**
#
# Рядки зберігаються компактно та ефективно завдяки незмінності.
#
# ---
#
# ✅ Найближчий змінний аналог рядка:
#
# * `list`
# * `bytearray`
#
# ---
#
# ### 🔹 `bool` — логічний тип
#
# ```python
# True
# False
# ```
#
# ---
#
# ### 🔹 `None`
#
# Спеціальне значення, що означає **відсутність значення**.
#
# ```python
# value = None
# ```
#
# ---
#
# ## 3. Оператори та вирази (Operators)
#
# ---
#
# ### 🔹 Математичні оператори
#
# | Оператор | Опис                  |
# | -------- | --------------------- |
# | `+`      | додавання             |
# | `-`      | віднімання            |
# | `*`      | множення              |
# | `**`     | піднесення до степеня |
#
# ---
#
# ### 🔹 Ділення
#
# #### `/` — стандартне ділення
#
# Завжди повертає `float`.
#
# ```python
# 10 / 4  # 2.5
# ```
#
# ---
#
# #### `//` — цілочисельне ділення
#
# Відкидає дробову частину.
#
# ```python
# 10 // 4  # 2
# ```
#
# ---
#
# #### `%` — остача від ділення
#
# ```python
# 10 % 4  # 2
# ```
#
# ---
#
# ### 🔹 Операції з рядками
#
# #### Конкатенація
#
# ```python
# "Hello" + " World"
# ```
#
# #### Повторення
#
# ```python
# "Hi" * 3
# ```
#
# ---
#
#
# ### 4🔹 Чому Python вимагає явного перетворення типів?
#
# Python поєднує в собі **динамічну**, але **строгу** типізацію.
#
# Це означає:
#
# - тип змінної **не потрібно оголошувати заздалегідь** (динамічність)
# - але кожен об'єкт у пам’яті **завжди має чітко визначений тип**
# - Python суворо контролює, які операції дозволені для цього типу
#
# ---
#
# #### 🧠 Філософія Python
#
# Один із головних принципів Python:
#
# > **Explicit is better than implicit**
# > (*Явне краще за неявне*)
#
# На відміну від мов типу JavaScript або PHP, Python **майже ніколи не виконує автоматичне перетворення типів**.
#
# ---
#
# ### Приклад
#
# У JavaScript:
#
# ```javascript
# "spam" + 5
# ````
#
# ✅ результат:
#
# ```
# "spam5"
# ```
#
# У Python:
#
# ```python
# "spam" + 5
# ```
#
# ❌ результат:
#
# ```
# TypeError: can only concatenate str (not "int") to str
# ```
#
# Python не намагається "вгадати", що саме ви хотіли зробити.
#
# ---
#
# ### ✅ Чому це добре?
#
# #### 1. Уникнення неоднозначності
#
# Якщо є:
#
# ```python
# "42" + 5
# ```
#
# Python не знає:
#
# * чи потрібно отримати число `47`
# * чи текст `"425"`
#
# Тому він зупиняє виконання.
#
# ---
#
# #### 2. Запобігання прихованим помилкам
#
# Явне перетворення змушує програміста чітко визначати намір:
#
# ```python
# int("42") + 5
# str(42) + "5"
# ```
#
# Помилка `TypeError` одразу показує логічну проблему в коді.
#
# ---
#
# ## 🦆 Duck Typing (Утина типізація)
#
# Щоб компенсувати строгість типів, Python використовує концепцію
# **утиної типізації (Duck Typing)**.
#
# Вона базується на відомому принципі:
#
# > *"Якщо воно виглядає як качка, плаває як качка і крякає як качка — це качка."*
#
# ---
#
# ### Що це означає в Python?
#
# Python **не перевіряє походження об'єкта**,
# його цікавить лише **поведінка**.
#
# Не важливо:
#
# * до якого класу належить об'єкт
# * хто його батьківський клас
#
# Важливо лише:
#
# ✅ чи підтримує він потрібні операції.
#
# ---
#
# ### Приклад: ітерація
#
# Функції байдуже, що саме передати:
#
# ```python
# for item in obj:
#     print(item)
# ```
#
# Це може бути:
#
# * `list`
# * `tuple`
# * `str`
# * генератор
# * власний клас
#
# Головне — щоб об'єкт підтримував ітерацію.
#
# ---
#
# ### Приклад: оператор `+`
#
# Об'єкту не обов'язково бути числом.
#
# Достатньо реалізувати магічний метод:
#
# ```python
# __add__()
# ```
#
# ---
#
# ## ⚖️ Баланс Python
#
# Python одночасно:
#
# ✅ **строгий** — не дозволяє змішувати несумісні типи
#
# ✅ **гнучкий** — дозволяє працювати з будь-якими об'єктами, що поводяться правильно
#
# ---
#
# Python контролює *що* ви робите з даними,
# але майже не обмежує *якими саме об'єктами* ви це робите.
#
# ---
#
# ### 🔹 `int(x)`
#
# ```python
# int("10")
# int(3.9)  # 3
# ```
#
# ---
#
# ### 🔹 `float(x)`
#
# ```python
# float(5)
# float("3.14")
# ```
#
# ---
#
# ### 🔹 `str(x)`
#
# ```python
# str(100)
# ```
#
# ---
#
# ## Висновок
#
# У Python:
#
# * змінні — це посилання на об'єкти
# * тип визначається автоматично
# * правильна робота з даними базується на розумінні типів і операцій над ними

# %% [markdown]
# # Зміні

# %% [markdown]
# # ✅ Task 1 — Зміна типу даних

# %%
print("📦 Уявіть склад Нової Пошти")

print("""
a = 7
b = a
a = 10
print(b)
""")

# %%
#@title 🔮 Яке значення матиме b ?
prediction_b = "" #@param {type:"string"}
if not require_student():
    raise SystemExit
if prediction_b.strip() == "":
    raise ValueError("⚠️ Введіть прогноз")

print("\n✅ Прогноз збережено:", prediction_b)

# %%
#@title 🐍 Результат та пояснення запусти Run

from IPython.display import Markdown, display

if not require_student():
    raise SystemExit

if prediction_b.strip() == "":
    raise ValueError("⚠️ Спочатку зробіть прогноз")

# ======================================
# 🐍 ВИКОНАННЯ КОДУ
# ======================================

a = 7
b = a

print("📦 Після b = a")
print("id(a):", id(a))
print("id(b):", id(b))

a = 10

print("\n📦 Після a = 10")
print("id(a):", id(a))
print("id(b):", id(b))

print("\n🐍 Python повернув:")
print("Значення b:", b)

print("\n🧠 Чи однакові коробки?")
print(id(a) == id(b))

# ======================================
# 🔓 ПОЯСНЕННЯ
# ======================================

display(Markdown("""
---
# ✅ Що сталося?
## 1️⃣ Початкове присвоювання
```python
a = 7
````
Python створює **об'єкт у памʼяті**:

```
📦 Box(id=...)
value = 7
type = int
```

і записує у таблиці імен:

```
a → 📦7
```
---
## 2️⃣ Копіювання змінної
```python
b = a
```
❗ Нова коробка **НЕ створюється**.

Обидві змінні посилаються на один і той самий об'єкт:
```
a → 📦7
b → 📦7
```
Саме тому їх `id()` однаковий.
---
## 3️⃣ Переприсвоювання
```python
a = 10
```
Python **не змінює стару коробку**.
Він:
✅ створює новий об'єкт
✅ змінює лише посилання змінної `a`
```
a → 📦10
b → 📦7
```
---

## ✅ Результат

```python
print(b)
```

повертає:

```
7
```
---

## 🔑 Головне правило Python

> **Змінна — це ярлик (посилання), а не контейнер із даними.**

Об'єкти живуть у памʼяті незалежно від імен.
"""))

# ===============================
# 📡 SUBMIT (якщо є функція)
# ===============================

try:
    submit_task(STUDENT_NAME, "Lesson1", "Task_b_prediction")
except:
    print("\nℹ️ submit_task() не підключений")

# %% [markdown]
# # ✅ TASK — None у Python

# %% [markdown]
# ### Що буде значенням `current_age` після виконання коду?
#
# ```python
# my_age = None
# current_age = my_age
# my_age = 25
#
# print(current_age)  # ???

# %%
#@title 🔮 Ваш прогноз
#
# my_age = None
# current_age = my_age
# my_age = 25
#
# print(current_age)  # ???

if not require_student():
    raise SystemExit

prediction_none = "" #@param {type:"string"}

if prediction_none.strip() == "":
    print("⚠️ Введіть прогноз перед виконанням наступної клітинки")
    raise SystemExit

print("✅ Прогноз збережено:", prediction_none)

# %%
#@title 🐍 Результат та пояснення запусти Run

from IPython.display import Markdown, display

if not require_student():
    raise SystemExit

try:
    print(f"{STUDENT_NAME} твій прогноз:" ,prediction_none)
except NameError:
    raise ValueError("⚠️ Спочатку зробіть прогноз у клітинці 🔮")


# ── EXECUTION ────────────────────────────────────────────

print("📦 Початковий стан")

my_age = None
current_age = my_age

print("my_age     :", my_age)
print("current_age:", current_age)
print("id(my_age)     :", id(my_age))
print("id(current_age):", id(current_age))

print("\n📦 Значення my_age змінилось")

my_age = 25

print("my_age     :", my_age)
print("current_age:", current_age)
print("id(my_age)     :", id(my_age))
print("id(current_age):", id(current_age))


# ── AUTO CHECK ───────────────────────────────────────────

correct_answer = "None"

if prediction_none.strip() == correct_answer:
    print("\n✅ Правильний прогноз!")
else:
    print("\n❌ Неправильно")
    print("Очікувалось:", correct_answer)


# ── ПОЯСНЕННЯ ────────────────────────────────────────────

display(Markdown("""
---

## ✅ Що сталося?

### 1️⃣ Початково

```python
my_age = None
current_age = my_age
```

Обидві змінні дивляться на **один** об'єкт `None`:

```
my_age      → 📦 None
current_age → 📦 None
```

---

### 2️⃣ None — це ОБ'ЄКТ

`None` — не порожнеча. Це реальний об'єкт типу `NoneType`.
У Python існує **лише один** `None` для всієї програми.

---

### 3️⃣ Переприсвоювання

```python
my_age = 25
```

Python створює нову коробку `📦 25` і переклеює **лише один** ярлик:

```
my_age      → 📦 25
current_age → 📦 None   ← не змінився!
```

---

### ✅ Висновок

> `None` означає: змінна існує, але значення ще не визначене.
> Змінні — це **ярлики**, а не коробки. Переклеювання одного не чіпає інших.
"""))


# ── SUBMIT ───────────────────────────────────────────────

try:
    submit_task(STUDENT_NAME, "Lesson1", "Task_none_reference")
except:
    print("ℹ️ submit_task() не підключений")

# %%
a = 5
print(id(a))

# %%
b = a
print(id(b))

# %% [markdown]
# #  Типи даних

# %%
# ======================================
# Перевірка типів змінних
# ======================================

int_value = 42
float_value = 42.0
string_value = "42"

print("🔍 Типи змінних у Python\n")

print(f"{'Змінна':<15} {'Значення':<10} {'Тип'}")
print("-" * 40)

print(f"{'int_value':<15} {int_value:<10} {type(int_value)}")
print(f"{'float_value':<15} {float_value:<10} {type(float_value)}")
print(f"{'string_value':<15} {string_value:<10} {type(string_value)}")

# %%
# ======================================
# Тип об'єкт у памʼяті
# ======================================

variables = {
    "int_value": 42,
    "int_value_2": 42,
    "float_value": 42.0,
    "float_value_2": 42.0,
    "string_value": "42",
    "string_value_2": "42"
}

print(f"{'Змінна':<15} {'Значення':<10} {'Тип':<20} {'id()'}")
print("-" * 65)

for name, value in variables.items():
    print(f"{name:<15} {str(value):<10} {str(type(value)):<20} {id(value)}")
# Out:
# Змінна          Значення   Тип                  id()
# -----------------------------------------------------------------
# int_value       42         <class 'int'>        11655688
# int_value_2     42         <class 'int'>        11655688
# float_value     42.0       <class 'float'>      140152772198064
# float_value_2   42.0       <class 'float'>      140152772198064
# string_value    42         <class 'str'>        140152959744928
# string_value_2  42         <class 'str'>        140152959744928

# %% [markdown]
# #Перетворення типу

# %%
print('I am ' + str(25))

# %%
value = '42'
converted = int(value)

print("Початкове значення =", value)
print("Тип початкового значення =", type(value))

print()

print("Після перетворення =", converted)
print("Тип після перетворення =", type(converted))


print("\n-------------------\n")

value = 1.2
converted = int(value)

print("Початкове значення =", value)
print("Тип початкового значення =", type(value))

print()

print("Після перетворення =", converted)
print("Тип після перетворення =", type(converted))


print("\n-------------------\n")

value = 1
converted = float(value)

print("Початкове значення =", value)
print("Тип початкового значення =", type(value))

print()

print("Після перетворення =", converted)
print("Тип після перетворення =", type(converted))


print("\n-------------------\n")

value = 42
converted = str(value)

print("Початкове значення =", value)
print("Тип початкового значення =", type(value))

print()

print("Після перетворення =", converted)
print("Тип після перетворення =", type(converted))

# %% [markdown]
# # ✅ Task  — Перетворення типу
#
# ## Передбачення
#
# Що, на вашу думку, виведе Python?
#
# ```python
# int(3.9)

# %%
# 🔹 Введіть свій прогноз
#@title 🔮 Ваш прогноз
prediction = "" #@param {type:"string"}

if prediction.strip() == "":
    raise ValueError("⚠️ Введіть прогноз")

print("✅ Прогноз збережено:", prediction)
# Out:
# ✅ Прогноз збережено: 3

# %%
#@title 🐍 Результат та пояснення запусти Run

from IPython.display import Markdown, display

if prediction.strip() == "":
    raise ValueError("⚠️ Спочатку зробіть прогноз")

print("\n✅ Ваш прогноз:", prediction)

# ===============================
# 🐍 РЕАЛЬНИЙ РЕЗУЛЬТАТ PYTHON
# ===============================

result = int(3.9)

print("\n🐍 Python повернув:", result)

# ===============================
# 🔓 UNLOCK ПОЯСНЕННЯ
# ===============================

display(Markdown(r"""
---

# ✅ Пояснення

## 🔹 Чому `int(3.9)` повертає `3`, а не `4`?

Виклик:

    int(3.9)

повертає:

    3

тому що функція **int()** не виконує математичного округлення.

---

## ✅ Як працює `int()`?

Функція `int()` виконує **усічення (truncation)** —
тобто просто **відкидає дробову частину**.

Приклади:

    int(3.9)   → 3
    int(3.1)   → 3
    int(-3.9)  → -3

Число округлюється **у бік нуля**.

---

## ⚠️ Важливо

`int()` ≠ округлення

Це лише зміна типу даних.

---

## 🔹 Коли потрібне справжнє округлення?

Використовується функція:

    round(3.9) → 4
    round(3.1) → 3

---

## 🔹 Порівняння

| Вираз | Результат | Поведінка |
|------|-----------|-----------|
| int(3.9) | 3 | усічення |
| round(3.9) | 4 | округлення |
| int(-3.9) | -3 | до нуля |
| round(-3.9) | -4 | математичне |

---

✅ **Правило**

- `int()` → відрізати дробову частину
- `round()` → округлити число
"""))

# ===============================
# 📡 SUBMIT (якщо є функція)
# ===============================

try:
    submit_task(STUDENT_NAME, "Lesson1", "Task_int_prediction")
    print("\n✅ Завдання зараховано")
except:
    print("\nℹ️ submit_task() не підключений")

# %% [markdown]
# # Оператори

# %% [markdown]
# ## Передбачення — що виведе Python?
#
# Код, який буде виконано:
#
# ```python
# print(1 + 2 * 3)
# ```
#
# **Варіанти:** `7` або `9`
#
# > ✏️ Запишіть свій прогноз, перш ніж запускати наступну клітинку.

# %%
# 🔹 Введіть свій прогноз
#@title 🔮 Ваш прогноз
#
# Код, який буде виконано:
#
#   print(1 + 2 * 3)
#
# Варіанти: 7  або  9

if not require_student():
    raise SystemExit

prediction_operators = "" #@param {type:"string"}

if prediction_operators.strip() == "":
    print("⚠️ Введіть прогноз перед виконанням наступної клітинки")
    raise SystemExit

print("✅ Прогноз збережено:", prediction_operators)

# %%
#@title 🐍 Результат та пояснення запусти Run

from IPython.display import Markdown, display

if not require_student():
    raise SystemExit

errors = []


# ── WARM-UP: пріоритет операторів ────────────────────────

print("=" * 45)
print("📦 Warm-up: пріоритет операторів")
print("=" * 45)
print("1 + 2 * 3 =", 1 + 2 * 3)


# ── AUTO CHECK: prediction ────────────────────────────────

correct_prediction = "7"
if prediction_operators.strip() == correct_prediction:
    print("✅ Прогноз правильний!")
else:
    print("❌ Прогноз неправильний. Очікувалось:", correct_prediction)
    errors.append("prediction")


# ── TASK 1: вираз == 9 ───────────────────────────────────

print("\n" + "=" * 45)
print("📝 Завдання 1: вираз з 1, 2, 3, +, * що дорівнює 9")
print("=" * 45)

result_warmup = (1 + 2) * 3   # ← рішення

print("result_warmup =", result_warmup)

if result_warmup == 9:
    print("✅ Правильно!")
else:
    print("❌ result_warmup має дорівнювати 9, отримано:", result_warmup)
    errors.append("task1")


# ── TASK 2: типи ділення ─────────────────────────────────

print("\n" + "=" * 45)
print("📝 Завдання 2: три типи ділення")
print("=" * 45)

print("Звичайне ділення  5 / 2  =", 5 / 2)
print("Цілочисельне      5 // 2 =", 5 // 2)
print("Остача            5 % 2  =", 5 % 2)


# ── TASK 3: math_result == 10 ────────────────────────────

print("\n" + "=" * 45)
print("📝 Завдання 3: вираз що дорівнює 10")
print("=" * 45)

math_result = 5 * 3 - 5 % 1 - 5   # ← одне з можливих рішень

print("math_result =", math_result)

if math_result == 10:
    print("✅ Правильно!")
else:
    print("❌ math_result має дорівнювати 10, отримано:", math_result)
    errors.append("task3")


# ── ПІДСУМОК ─────────────────────────────────────────────

print("\n" + "=" * 45)
if not errors:
    print("🏆 Всі завдання виконано правильно!")
else:
    print("⚠️ Є помилки в:", ", ".join(errors))
print("=" * 45)


# ── ПОЯСНЕННЯ ────────────────────────────────────────────

display(Markdown("""
---

## ✅ Що сталося?

### 1️⃣ Пріоритет операторів

```python
1 + 2 * 3  →  1 + 6  →  7
```

Python рахує **множення раніше** за додавання — так само, як у математиці.
Щоб змінити порядок — використовуй дужки:

```python
(1 + 2) * 3  →  3 * 3  →  9
```

---

### 2️⃣ Три типи ділення

| Оператор | Приклад  | Результат | Що повертає          |
|----------|----------|-----------|----------------------|
| `/`      | `5 / 2`  | `2.5`     | завжди `float`       |
| `//`     | `5 // 2` | `2`       | ціла частина (`int`) |
| `%`      | `5 % 2`  | `1`       | остача від ділення   |

---

### 3️⃣ Таблиця пріоритетів (від вищого до нижчого)

```
()          ← найвищий
**          ← степінь
*, /, //, % ← множення / ділення
+, -        ← додавання / віднімання
```

> **Правило:** якщо сумніваєшся — постав дужки. Код стане зрозумілішим.
"""))


# ── SUBMIT ───────────────────────────────────────────────

try:
    submit_task(STUDENT_NAME, "Lesson1", "Task_operators")
except:
    print("ℹ️ submit_task() не підключений")

# %%
# TODO: Напишіть вираз з числами 1, 2, 3, + і *, який дорівнює 9.
result_warmup = None

# assert result_warmup == 9

# %%
print('Звичайне ділення:', 5 / 2)
print('Цілочисельне ділення:', 5 // 2)
print('Остача:', 5 % 2)

# %% [markdown]
# # Рядки

# %% [markdown]
# # 🔤 Робота з символами в Python: індекси, `ord()` та `chr()`
#
# Цей урок показує **як Python працює з текстом на рівні символів**.
# Це фундамент для:
#
# - ✅ рядків
# - ✅ кодування
# - ✅ шифрування
# - ✅ NLP
# - ✅ AI алгоритмів

# %% [markdown]
# ---
# ## 🐍 1. Рядок — це послідовність символів
#
# Python зберігає рядок як пронумеровану послідовність:
#
# ```
# P   y   t   h   o   n
# 0   1   2   3   4   5
# ```
#
# Доступ до символів — через **індекс** у квадратних дужках.

# %%
word = 'Python'

print("Рядок:", word)
print("word[0]:", word[0])   # перший символ
print("word[1]:", word[1])   # другий символ
print("word[5]:", word[5])   # останній символ (індекс 5)

# %% [markdown]
# ---
# ## 🔙 Негативні індекси
#
# Python дозволяє рахувати **з кінця**:
#
# ```
# P    y    t    h    o    n
# -6  -5   -4   -3   -2   -1
# ```
#
# Зручно для: останнього символу, розширення файлу, кінця рядка.

# %%
word = 'Python'

print("word[-1]:", word[-1])   # останній
print("word[-2]:", word[-2])   # передостанній
print("word[-6]:", word[-6])   # те саме, що word[0]

# %% [markdown]
# ---
# ## 🔢 2. Символ = число
#
# Комп'ютер не розуміє літери — він працює лише з числами.
# Кожен символ має числовий код (**Unicode / ASCII**).
#
# | Функція | Що робить           | Приклад              |
# |---------|---------------------|----------------------|
# | `ord()` | символ → число      | `ord('A')` → `65`    |
# | `chr()` | число → символ      | `chr(66)` → `'B'`    |
#
# Це **зворотні операції**:
# ```python
# chr(ord('A')) == 'A'   # True
# ```

# %%
# ord() — символ → число
print("ord('A'):", ord('A'))
print("ord('a'):", ord('a'))
print("ord('z'):", ord('z'))

print()

# chr() — число → символ
print("chr(65):", chr(65))
print("chr(66):", chr(66))
print("chr(90):", chr(90))

print()

# Зворотність
print("chr(ord('A')) == 'A':", chr(ord('A')) == 'A')

# %% [markdown]
# ---
# ## 🔐 Для чого це використовується
#
# ### 1. Шифрування (Caesar cipher) — зсунути букву
# ```python
# chr(ord('A') + 1)   # → 'B'
# ```
#
# ### 2. Перевірка типу символу
# ```python
# if ord(char) >= ord('a') and ord(char) <= ord('z'):
#     ...  # маленька літера
# ```
#
# ### 3. Генерація алфавіту
# ```python
# for i in range(ord('a'), ord('z') + 1):
#     print(chr(i))
# ```

# %%
# 1. Зсув літери (шифрування)
print("A + 1 →", chr(ord('A') + 1))
print("a + 3 →", chr(ord('a') + 3))

print()

# 2. Перевірка: чи символ — маленька літера?
char = 'g'
if ord(char) >= ord('a') and ord(char) <= ord('z'):
    print(f"'{char}' — маленька літера ✅")

print()

# 3. Генерація першых 5 літер алфавіту
print("Перші 5 літер:", end=" ")
for i in range(ord('a'), ord('a') + 5):
    print(chr(i), end=" ")
print()

# %% [markdown]
# ---
#
# **Знайдіть код `'z'`, відніміть 25 і поверніть символ.**
#
# Покроково:
#
# ```
# ord('z')        →  122
# 122 - 25        →  97
# chr(97)         →  'a'
# ```
#
# > ✏️ Спробуйте самостійно, потім запустіть клітинку нижче.

# %%
ord('z')

# %%
122-25

# %%
chr(97)

# %%
# 🧩 Завдання — покроковий розбір

step1 = ord('z')
print("ord('z')  =", step1)

step2 = step1 - 25
print("122 - 25  =", step2)

step3 = chr(step2)
print("chr(97)   =", step3)

print()

# Рішення одним рядком
mystery_char = chr(ord('z') - 25)
print("mystery_char =", mystery_char)

assert mystery_char == 'a', "Перевірте формулу!"
print("✅ Правильно!")

# %% [markdown]
# # Міні‑проєкт
# ## 📦 Фінальний проєкт — Таємнича коробка Нової Пошти

# %% [markdown]
# ## Висновок
#
# 1. Змінна — це ярлик.
# 2. Python динамічно типізований.
# 3. Рядки незмінні.
# 4. Пріоритет операцій важливий.
# 5. Текст — це числа.
